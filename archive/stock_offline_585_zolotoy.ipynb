# %%
import datetime as dt
import pandas as pd
import numpy as np
import pymssql
import warnings
import calendar
import locale
import glob
import os

warnings.filterwarnings('ignore')
pd.set_option('use_inf_as_na', True)
pd.options.display.max_columns = None
pd.set_option('float_format', '{:.2f}'.format)
locale.setlocale(locale.LC_ALL, 'ru_RU.UTF-8')
# Out:
# 'ru_RU.UTF-8'

# %%
# SQL-скрипт ниже выгружает данные по остаткам с БД Staging, доступ к ней выдаётся по учётной записи Windows по согласованию

conn = pymssql.connect(server='AX-SQL', database='Staging')
cursor = conn.cursor()

sql = f'''
SELECT [Код склада], [Название склада], [Цена Закупки за 1 шт. (упр сс с НДС за единицу)], [Группа цен],
[Товарное направление], [Товарная группа], [Проба], [Цена Розн., за шт],  [Запрет скидки],
[Код товара],  [Артикул поставщика], [Чистый вес], [ШК], [Общий вес], [Скидка на изделии], [Тип изделия 1]
from [Staging].[Reports].[Remainings_8h]
where [Товарное направление] in (N'БК', N'ЦБ')
'''

sql_query = pd.read_sql_query(sql, conn)
df = pd.DataFrame(sql_query)

# %%
df
# Out:
#         Код склада                           Название склада  \
# 0             3742            Казань, Победы, 91, ТЦ «Южный»
# 1             3742            Казань, Победы, 91, ТЦ «Южный»
# 2             3742            Казань, Победы, 91, ТЦ «Южный»
# 3             3742            Казань, Победы, 91, ТЦ «Южный»
# 4             3742            Казань, Победы, 91, ТЦ «Южный»
# ...            ...                                       ...
# 1462182       3758  Юрга, Машиностроителей, 32, ТЦ "Спутник"
# 1462183       3758  Юрга, Машиностроителей, 32, ТЦ "Спутник"
# 1462184       3758  Юрга, Машиностроителей, 32, ТЦ "Спутник"
# 1462185       3758  Юрга, Машиностроителей, 32, ТЦ "Спутник"
# 1462186       3758  Юрга, Машиностроителей, 32, ТЦ "Спутник"
#
#          Цена Закупки за 1 шт. (упр сс с НДС за единицу)  \
# 0                                                5724.41
# 1                                                 442.22
# 2                                                1878.02
# 3                                                6702.37
# 4                                                3299.10
# ...                                                  ...
# 1462182                                          2576.53
# 1462183                                         10048.95
# 1462184                                          3871.35
# 1462185                                         15715.69
# 1462186                                          4030.68
#
#                         Группа цен Товарное направление  Товарная группа  \
# 0                         ИФ.БК_СР                   БК  БК ПОДВЕС КУЛЬТ
# 1                        ИФ.БК_ДЕШ                   БК        БК СЕРЬГИ
# 2                        ИФ.БК_ДЕШ                   БК        БК СЕРЬГИ
# 3          ЦБ_ПУСТОТЕЛЫЕ <=3 ГРАММ                   ЦБ      ЦБ БРАСЛЕТЫ
# 4        ЦБ_ПУСТОТЕЛЫЕ <=1,5 ГРАММ                   ЦБ      ЦБ БРАСЛЕТЫ
# ...                            ...                  ...              ...
# 1462182                   ШОК_ЦЕНА                   ЦБ          ЦБ ЦЕПИ
# 1462183                   ИФ.БК_СР                   БК       БК ПЕЧАТКИ
# 1462184                  ИФ.БК_ДЕШ                   БК        БК СЕРЬГИ
# 1462185        ЦБ_АВТОМАТ >3 ГРАММ                   ЦБ          ЦБ ЦЕПИ
# 1462186                   ИФ.БК_СР                   БК  БК КОЛЬЦА ОБРУЧ
#
#         Проба  Цена Розн., за шт Запрет скидки  Код товара Артикул поставщика  \
# 0         585           31428.00           Нет  ТОВ0785969              32177
# 1         585            4755.00           Нет  ТОВ0786109              60053
# 2         585           12667.00           Нет  ТОВ0793783           12.10_10
# 3         585           28518.00           Нет  ТОВ0987998    НБ12-028ПГ D0,5
# 4         585           16310.00           Нет  ТОВ0988008   НБ12-076ПГ D0,35
# ...       ...                ...           ...         ...                ...
# 1462182   375            6344.00            Да  ТОВ1067410   30-91-0025-30028
# 1462183   585           75042.00           Нет  ТОВ1067425         П.01-04-01
# 1462184   585           25863.00           Нет  ТОВ1070574   12-00-0000-26417
# 1462185   585           77161.00           Нет  ТОВ1071206        40-54030-11
# 1462186   585           36533.00           Нет  ТОВ1072477        КОС 04-01КБ
#
#          Чистый вес             ШК  Общий вес  Скидка на изделии  \
# 0              1.62  2078608701854       1.62              24.00
# 1              0.19  2078498728971       0.19              49.00
# 2              0.53  2078610410586       0.53              35.00
# 3              1.47  2078608366151       1.47              25.00
# 4              0.70  2078608727388       0.70              42.00
# ...             ...            ...        ...                ...
# 1462182        1.59  2078518907669       1.59               0.00
# 1462183        3.79  2078587344921       3.79              22.00
# 1462184        1.11  2078609750865       1.11              35.00
# 1462185        5.11  2078606445028       5.11               6.00
# 1462186        2.38  2078425762214       2.38              20.00
#
#               Тип изделия 1
# 0          ПОДВЕС КУЛЬТОВЫЙ
# 1                   ПИРСИНГ
# 2              СЕРЬГИ-КОНГО
# 3                   БРАСЛЕТ
# 4                   БРАСЛЕТ
# ...                     ...
# 1462182                ЦЕПЬ
# 1462183      КОЛЬЦО ПЕЧАТКА
# 1462184              СЕРЬГИ
# 1462185                ЦЕПЬ
# 1462186  КОЛЬЦО ОБРУЧАЛЬНОЕ
#
# [1462187 rows x 16 columns]

# %%
df['Код склада'] = df['Код склада'].astype('float64')

# %%
df.head()
# Out:
#    Код склада                 Название склада  \
# 0     3742.00  Казань, Победы, 91, ТЦ «Южный»
# 1     3742.00  Казань, Победы, 91, ТЦ «Южный»
# 2     3742.00  Казань, Победы, 91, ТЦ «Южный»
# 3     3742.00  Казань, Победы, 91, ТЦ «Южный»
# 4     3742.00  Казань, Победы, 91, ТЦ «Южный»
#
#    Цена Закупки за 1 шт. (упр сс с НДС за единицу)                 Группа цен  \
# 0                                          5724.41                   ИФ.БК_СР
# 1                                           442.22                  ИФ.БК_ДЕШ
# 2                                          1878.02                  ИФ.БК_ДЕШ
# 3                                          6702.37    ЦБ_ПУСТОТЕЛЫЕ <=3 ГРАММ
# 4                                          3299.10  ЦБ_ПУСТОТЕЛЫЕ <=1,5 ГРАММ
#
#   Товарное направление  Товарная группа Проба  Цена Розн., за шт  \
# 0                   БК  БК ПОДВЕС КУЛЬТ   585           31428.00
# 1                   БК        БК СЕРЬГИ   585            4755.00
# 2                   БК        БК СЕРЬГИ   585           12667.00
# 3                   ЦБ      ЦБ БРАСЛЕТЫ   585           28518.00
# 4                   ЦБ      ЦБ БРАСЛЕТЫ   585           16310.00
#
#   Запрет скидки  Код товара Артикул поставщика  Чистый вес             ШК  \
# 0           Нет  ТОВ0785969              32177        1.62  2078608701854
# 1           Нет  ТОВ0786109              60053        0.19  2078498728971
# 2           Нет  ТОВ0793783           12.10_10        0.53  2078610410586
# 3           Нет  ТОВ0987998    НБ12-028ПГ D0,5        1.47  2078608366151
# 4           Нет  ТОВ0988008   НБ12-076ПГ D0,35        0.70  2078608727388
#
#    Общий вес  Скидка на изделии     Тип изделия 1
# 0       1.62              24.00  ПОДВЕС КУЛЬТОВЫЙ
# 1       0.19              49.00           ПИРСИНГ
# 2       0.53              35.00      СЕРЬГИ-КОНГО
# 3       1.47              25.00           БРАСЛЕТ
# 4       0.70              42.00           БРАСЛЕТ

# %%
date_now = dt.datetime.today()
day = dt.datetime.today().day - 1
year = dt.datetime.today().year
month = dt.datetime.today().month

# %%
path = r'\\gold585.int\uk\Общее хранилище файлов\Служба аналитики\Архив_отчеты\Продажи\По дням'
list_of_files = glob.glob(path + '\*.xlsx') 
latest_file = max(list_of_files, key=os.path.getctime)
name_month = date_now.strftime('%b')

# %%
# смотрим, прочитался ли актуальный файл
if f'{path}\\МОТИВАЦИОННЫЙ выполнение плана продаж {name_month} {year} - {day}.xlsx' == str(latest_file):
    print('прочитан актуальный файл')
else:
    print(''' 
нужный на сегодня файл отсутствует

ответственный за загрузку: Илларионов Иван
загружает этот файл после формирования своего ежедневного отчёта примерно в 13:00''')
# Out:
#
# нужный на сегодня файл отсутствует
#
# ответственный за загрузку: Илларионов Иван
# загружает этот файл после формирования своего ежедневного отчёта примерно в 13:00

# %%
sklad = pd.read_excel(latest_file, sheet_name = 'Продажи по ассортименту', header = 2)
sklad = sklad[['Unnamed: 0','Торговая марка', 'Юр лицо', 'Код склада', 'Дата открытия объекта', 'Код объекта', 'Город', 'Наименование объекта']]
sklad1 = sklad[['Код склада', 'Код объекта']].drop_duplicates().reset_index(drop=True)
sklad1 = sklad1[sklad1['Код объекта'].notna()]

# %%
# отбираем кбк без франчайзи(у них кбк начинается с "8")
sklad1['Код объекта'] = sklad1['Код объекта'].astype(str)
sklad1['8'] = sklad1['Код объекта'].apply(lambda x: x[0])
sklad1 = sklad1[sklad1['8'] != '8']

# %%
df = df.merge(sklad1, left_on='Код склада', right_on = 'Код склада', how='inner')

# %%
# можно использовать для расчета чистый вес или общий вес. Чистый вес и общий вес должны совпадать
df['Бирка за грамм'] = df['Цена Розн., за шт'] / df['Чистый вес']

# %%
df['Скидка на изделии'] = df['Скидка на изделии'].astype(float)
df['Скидка на изделии'] = (df['Скидка на изделии'] / 100).round(2)

# %%
# Скидка по ПЛ(программе лояльности) не постоянная, она постоянно меняется. 
# Всегда нужно уточнять актуальный промокод у Николая или у Тани
discount = 0.8

df['Скидка_по_ПЛ'] = np.where(
    df['Запрет скидки']=='Да', 1, 
    np.where(
        (df['Запрет скидки']=='Нет') & ((df['Товарное направление']=='ДК')|
                                        (df['Товарное направление']=='ПДК')|
                                        (df['Товарное направление']=='БК')|
                                        (df['Товарное направление']=='ЦБ')|
                                        (df['Товарное направление']=='ИФ')|
                                        (df['Товарное направление']=='СИ')|
                                        (df['Товарное направление']=='ДФРС')|
                                        (df['Товарное направление']=='ВЫРИЦА')|
                                        (df['Товарное направление']=='ЧАСЫ')), discount, 1
        )
    )

# %%
df['Запрет скидки'].value_counts()
# Out:
# Запрет скидки
# Нет    1267949
# Да       60511
# Name: count, dtype: int64

# %%
df['Цена после ПЛ'] = np.where(
    df['Запрет скидки'] == 'Нет', df['Цена Розн., за шт'] * df['Скидка_по_ПЛ'], df['Цена Розн., за шт']
    )

# %%
df['Цена за грамм после ПЛ'] = df['Цена после ПЛ'] / df['Чистый вес']

# %%
df['Проба'].unique().tolist()
# Out:
# ['585', '375', '', '750']

# %%
df
# Out:
#          Код склада                 Название склада  \
# 0           3742.00  Казань, Победы, 91, ТЦ «Южный»
# 1           3742.00  Казань, Победы, 91, ТЦ «Южный»
# 2           3742.00  Казань, Победы, 91, ТЦ «Южный»
# 3           3742.00  Казань, Победы, 91, ТЦ «Южный»
# 4           3742.00  Казань, Победы, 91, ТЦ «Южный»
# ...             ...                             ...
# 1328455     3927.00     Южно-Сахалинск, Ленина, 218
# 1328456     3927.00     Южно-Сахалинск, Ленина, 218
# 1328457     3927.00     Южно-Сахалинск, Ленина, 218
# 1328458     3927.00     Южно-Сахалинск, Ленина, 218
# 1328459     3927.00     Южно-Сахалинск, Ленина, 218
#
#          Цена Закупки за 1 шт. (упр сс с НДС за единицу)  \
# 0                                                5724.41
# 1                                                 442.22
# 2                                                1878.02
# 3                                                6702.37
# 4                                                3299.10
# ...                                                  ...
# 1328455                                          2779.60
# 1328456                                          4376.78
# 1328457                                         17025.75
# 1328458                                         18247.84
# 1328459                                         17243.28
#
#                         Группа цен Товарное направление  Товарная группа  \
# 0                         ИФ.БК_СР                   БК  БК ПОДВЕС КУЛЬТ
# 1                        ИФ.БК_ДЕШ                   БК        БК СЕРЬГИ
# 2                        ИФ.БК_ДЕШ                   БК        БК СЕРЬГИ
# 3          ЦБ_ПУСТОТЕЛЫЕ <=3 ГРАММ                   ЦБ      ЦБ БРАСЛЕТЫ
# 4        ЦБ_ПУСТОТЕЛЫЕ <=1,5 ГРАММ                   ЦБ      ЦБ БРАСЛЕТЫ
# ...                            ...                  ...              ...
# 1328455                     ИФ_375                   БК        БК СЕРЬГИ
# 1328456                     ИФ_375                   БК        БК СЕРЬГИ
# 1328457                  ИФ.БК_ДОР                   БК       БК ПЕЧАТКИ
# 1328458                  ИФ.БК_ДОР                   БК       БК ПЕЧАТКИ
# 1328459                  ИФ.БК_ДОР                   БК       БК ПЕЧАТКИ
#
#         Проба  Цена Розн., за шт Запрет скидки  Код товара  \
# 0         585           31428.00           Нет  ТОВ0785969
# 1         585            4755.00           Нет  ТОВ0786109
# 2         585           12667.00           Нет  ТОВ0793783
# 3         585           28518.00           Нет  ТОВ0987998
# 4         585           16310.00           Нет  ТОВ0988008
# ...       ...                ...           ...         ...
# 1328455   375           21209.00           Нет  ТОВ1258873
# 1328456   375           33400.00           Нет  ТОВ1258876
# 1328457   585           85750.00           Нет  ТОВ1315711
# 1328458   585           91875.00           Нет  ТОВ1315711
# 1328459   585           86100.00           Нет  ТОВ1315712
#
#            Артикул поставщика  Чистый вес             ШК  Общий вес  \
# 0                       32177        1.62  2078608701854       1.62
# 1                       60053        0.19  2078498728971       0.19
# 2                    12.10_10        0.53  2078610410586       0.53
# 3             НБ12-028ПГ D0,5        1.47  2078608366151       1.47
# 4            НБ12-076ПГ D0,35        0.70  2078608727388       0.70
# ...                       ...         ...            ...        ...
# 1328455  18-91-0000-29325#375        1.27  2078609203795       1.27
# 1328456  18-91-0000-23589#375        2.00  2078609203350       2.00
# 1328457            П.11-24-01        4.90  2078610753842       4.90
# 1328458            П.11-24-01        5.25  2078610721982       5.25
# 1328459            П.11-24-01        4.92  2078610518882       4.92
#
#          Скидка на изделии     Тип изделия 1 Код объекта  8  Бирка за грамм  \
# 0                     0.24  ПОДВЕС КУЛЬТОВЫЙ    2-18-018  2        19400.00
# 1                     0.49           ПИРСИНГ    2-18-018  2        25026.32
# 2                     0.35      СЕРЬГИ-КОНГО    2-18-018  2        23854.99
# 3                     0.25           БРАСЛЕТ    2-18-018  2        19400.00
# 4                     0.42           БРАСЛЕТ    2-18-018  2        23266.76
# ...                    ...               ...         ... ..             ...
# 1328455               0.45            СЕРЬГИ    3-09-030  3        16686.86
# 1328456               0.45            СЕРЬГИ    3-09-030  3        16683.32
# 1328457               0.20    КОЛЬЦО ПЕЧАТКА    3-09-030  3        17503.57
# 1328458               0.20    КОЛЬЦО ПЕЧАТКА    3-09-030  3        17500.00
# 1328459               0.20    КОЛЬЦО ПЕЧАТКА    3-09-030  3        17500.00
#
#          Скидка_по_ПЛ  Цена после ПЛ  Цена за грамм после ПЛ
# 0                0.80       25142.40                15520.00
# 1                0.80        3804.00                20021.05
# 2                0.80       10133.60                19083.99
# 3                0.80       22814.40                15520.00
# 4                0.80       13048.00                18613.41
# ...               ...            ...                     ...
# 1328455          0.80       16967.20                13349.49
# 1328456          0.80       26720.00                13346.65
# 1328457          0.80       68600.00                14002.86
# 1328458          0.80       73500.00                14000.00
# 1328459          0.80       68880.00                14000.00
#
# [1328460 rows x 22 columns]

# %%
df = df.query("`Проба` == '585'")

# %%
df['Наценка'] = df['Цена после ПЛ']  / df['Цена Закупки за 1 шт. (упр сс с НДС за единицу)'] - 1

# %%
df['Товарная группа'].value_counts()
# Out:
# Товарная группа
# ЦБ ЦЕПИ            307139
# БК КОЛЬЦА ОБРУЧ    219919
# ЦБ БРАСЛЕТЫ        216876
# БК СЕРЬГИ          167969
# БК ПОДВЕС КУЛЬТ    149247
# БК КОЛЬЦА           69729
# БК ПОДВЕС ДЕКОР     42064
# БК ПЕЧАТКИ          11079
# ОПТ БК               5359
# ОПТ КОНГО            1863
# ОПТ ОБРУЧИ            468
# БК АКСЕССУАРЫ         102
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1191814 entries, 0 to 1328459
# Data columns (total 23 columns):
#  #   Column                                           Non-Null Count    Dtype
# ---  ------                                           --------------    -----
#  0   Код склада                                       1191814 non-null  float64
#  1   Название склада                                  1191814 non-null  object
#  2   Цена Закупки за 1 шт. (упр сс с НДС за единицу)  1191814 non-null  float64
#  3   Группа цен                                       1191814 non-null  object
#  4   Товарное направление                             1191814 non-null  object
#  5   Товарная группа                                  1191814 non-null  object
#  6   Проба                                            1191814 non-null  object
#  7   Цена Розн., за шт                                1191814 non-null  float64
#  8   Запрет скидки                                    1191814 non-null  object
#  9   Код товара                                       1191814 non-null  object
#  10  Артикул поставщика                               1191814 non-null  object
#  11  Чистый вес                                       1191814 non-null  float64
#  12  ШК                                               1191814 non-null  object
#  13  Общий вес                                        1191814 non-null  float64
#  14  Скидка на изделии                                1191814 non-null  float64
#  15  Тип изделия 1                                    1191814 non-null  object
#  16  Код объекта                                      1191814 non-null  object
#  17  8                                                1191814 non-null  object
#  18  Бирка за грамм                                   1191814 non-null  float64
#  19  Скидка_по_ПЛ                                     1191814 non-null  float64
#  20  Цена после ПЛ                                    1191814 non-null  float64
#  21  Цена за грамм после ПЛ                           1191814 non-null  float64
#  22  Наценка                                          1191814 non-null  float64
# dtypes: float64(11), object(12)
# memory usage: 218.2+ MB

# %%
df
# Out:
#          Код склада                 Название склада  \
# 0           3742.00  Казань, Победы, 91, ТЦ «Южный»
# 1           3742.00  Казань, Победы, 91, ТЦ «Южный»
# 2           3742.00  Казань, Победы, 91, ТЦ «Южный»
# 3           3742.00  Казань, Победы, 91, ТЦ «Южный»
# 4           3742.00  Казань, Победы, 91, ТЦ «Южный»
# ...             ...                             ...
# 1328440     3927.00     Южно-Сахалинск, Ленина, 218
# 1328452     3927.00     Южно-Сахалинск, Ленина, 218
# 1328457     3927.00     Южно-Сахалинск, Ленина, 218
# 1328458     3927.00     Южно-Сахалинск, Ленина, 218
# 1328459     3927.00     Южно-Сахалинск, Ленина, 218
#
#          Цена Закупки за 1 шт. (упр сс с НДС за единицу)  \
# 0                                                5724.41
# 1                                                 442.22
# 2                                                1878.02
# 3                                                6702.37
# 4                                                3299.10
# ...                                                  ...
# 1328440                                          3782.22
# 1328452                                          3064.09
# 1328457                                         17025.75
# 1328458                                         18247.84
# 1328459                                         17243.28
#
#                             Группа цен Товарное направление  Товарная группа  \
# 0                             ИФ.БК_СР                   БК  БК ПОДВЕС КУЛЬТ
# 1                            ИФ.БК_ДЕШ                   БК        БК СЕРЬГИ
# 2                            ИФ.БК_ДЕШ                   БК        БК СЕРЬГИ
# 3              ЦБ_ПУСТОТЕЛЫЕ <=3 ГРАММ                   ЦБ      ЦБ БРАСЛЕТЫ
# 4            ЦБ_ПУСТОТЕЛЫЕ <=1,5 ГРАММ                   ЦБ      ЦБ БРАСЛЕТЫ
# ...                                ...                  ...              ...
# 1328440                       ИФ.БК_СР                   БК  БК ПОДВЕС КУЛЬТ
# 1328452  ЦБ_КОЛЬЕ, БРАС СО ВСТАВ <=1,5                   ЦБ      ЦБ БРАСЛЕТЫ
# 1328457                      ИФ.БК_ДОР                   БК       БК ПЕЧАТКИ
# 1328458                      ИФ.БК_ДОР                   БК       БК ПЕЧАТКИ
# 1328459                      ИФ.БК_ДОР                   БК       БК ПЕЧАТКИ
#
#         Проба  Цена Розн., за шт Запрет скидки  Код товара Артикул поставщика  \
# 0         585           31428.00           Нет  ТОВ0785969              32177
# 1         585            4755.00           Нет  ТОВ0786109              60053
# 2         585           12667.00           Нет  ТОВ0793783           12.10_10
# 3         585           28518.00           Нет  ТОВ0987998    НБ12-028ПГ D0,5
# 4         585           16310.00           Нет  ТОВ0988008   НБ12-076ПГ D0,35
# ...       ...                ...           ...         ...                ...
# 1328440   585           25969.00           Нет  ТОВ1256990   51-02-0000-10776
# 1328452   585           22602.00           Нет  ТОВ1257567   47-02-0001-11188
# 1328457   585           85750.00           Нет  ТОВ1315711         П.11-24-01
# 1328458   585           91875.00           Нет  ТОВ1315711         П.11-24-01
# 1328459   585           86100.00           Нет  ТОВ1315712         П.11-24-01
#
#          Чистый вес             ШК  Общий вес  Скидка на изделии  \
# 0              1.62  2078608701854       1.62               0.24
# 1              0.19  2078498728971       0.19               0.49
# 2              0.53  2078610410586       0.53               0.35
# 3              1.47  2078608366151       1.47               0.25
# 4              0.70  2078608727388       0.70               0.42
# ...             ...            ...        ...                ...
# 1328440        1.54  2078605005150       1.54               0.34
# 1328452        1.10  2078601121738       1.11               0.26
# 1328457        4.90  2078610753842       4.90               0.20
# 1328458        5.25  2078610721982       5.25               0.20
# 1328459        4.92  2078610518882       4.92               0.20
#
#             Тип изделия 1 Код объекта  8  Бирка за грамм  Скидка_по_ПЛ  \
# 0        ПОДВЕС КУЛЬТОВЫЙ    2-18-018  2        19400.00          0.80
# 1                 ПИРСИНГ    2-18-018  2        25026.32          0.80
# 2            СЕРЬГИ-КОНГО    2-18-018  2        23854.99          0.80
# 3                 БРАСЛЕТ    2-18-018  2        19400.00          0.80
# 4                 БРАСЛЕТ    2-18-018  2        23266.76          0.80
# ...                   ...         ... ..             ...           ...
# 1328440  ПОДВЕС КУЛЬТОВЫЙ    3-09-030  3        16873.94          0.80
# 1328452           БРАСЛЕТ    3-09-030  3        20472.83          0.80
# 1328457    КОЛЬЦО ПЕЧАТКА    3-09-030  3        17503.57          0.80
# 1328458    КОЛЬЦО ПЕЧАТКА    3-09-030  3        17500.00          0.80
# 1328459    КОЛЬЦО ПЕЧАТКА    3-09-030  3        17500.00          0.80
#
#          Цена после ПЛ  Цена за грамм после ПЛ  Наценка
# 0             25142.40                15520.00     3.39
# 1              3804.00                20021.05     7.60
# 2             10133.60                19083.99     4.40
# 3             22814.40                15520.00     2.40
# 4             13048.00                18613.41     2.96
# ...                ...                     ...      ...
# 1328440       20775.20                13499.16     4.49
# 1328452       18081.60                16378.26     4.90
# 1328457       68600.00                14002.86     3.03
# 1328458       73500.00                14000.00     3.03
# 1328459       68880.00                14000.00     2.99
#
# [1191814 rows x 23 columns]

# %%
result = df.groupby(by = 'Товарная группа', as_index = False)[['Цена после ПЛ', 'Чистый вес', 'Цена Закупки за 1 шт. (упр сс с НДС за единицу)']].agg('sum')

# %%
result = result[result['Товарная группа'].str.contains('БК КОЛЬЦА|БК КОЛЬЦА ОБРУЧ|БК ПОДВЕС ДЕКОР|БК ПОДВЕС КУЛЬТ|БК СЕРЬГИ|ЦБ БРАСЛЕТЫ|ЦБ ЦЕПИ')]

# %%
result
# Out:
#     Товарная группа  Цена после ПЛ  Чистый вес  \
# 1         БК КОЛЬЦА  1938698301.76   143315.43
# 2   БК КОЛЬЦА ОБРУЧ  8154052460.60   619279.05
# 4   БК ПОДВЕС ДЕКОР   652807799.08    45531.61
# 5   БК ПОДВЕС КУЛЬТ  3391888551.56   240007.34
# 6         БК СЕРЬГИ  4757640534.36   326482.73
# 10      ЦБ БРАСЛЕТЫ  8793803096.60   650990.37
# 11          ЦБ ЦЕПИ 16325970556.40  1273458.10
#
#     Цена Закупки за 1 шт. (упр сс с НДС за единицу)
# 1                                      396793837.06
# 2                                     1595026516.48
# 4                                      127235829.80
# 5                                      708090474.68
# 6                                     1005259053.54
# 10                                    2115354097.47
# 11                                    4067542255.99

# %%
result['Наценка остатки оффлайн'] = result['Цена после ПЛ'] * 0.8 * 0.7 / result['Цена Закупки за 1 шт. (упр сс с НДС за единицу)'] - 1

# %%
result['10%+20%'] = round(result['Цена после ПЛ'] * 0.8 * 0.7 * 0.9 / result['Чистый вес'], 1).astype('int')

# %%
result.columns = ['tg', 'price', 'weight', 'cost_price', 'margin', 'with_discount_1']

# %%
result
# Out:
#                  tg          price     weight    cost_price  margin  \
# 1         БК КОЛЬЦА  1938698301.76  143315.43  396793837.06    1.74
# 2   БК КОЛЬЦА ОБРУЧ  8154052460.60  619279.05 1595026516.48    1.86
# 4   БК ПОДВЕС ДЕКОР   652807799.08   45531.61  127235829.80    1.87
# 5   БК ПОДВЕС КУЛЬТ  3391888551.56  240007.34  708090474.68    1.68
# 6         БК СЕРЬГИ  4757640534.36  326482.73 1005259053.54    1.65
# 10      ЦБ БРАСЛЕТЫ  8793803096.60  650990.37 2115354097.47    1.33
# 11          ЦБ ЦЕПИ 16325970556.40 1273458.10 4067542255.99    1.25
#
#     with_discount_1
# 1              6817
# 2              6636
# 4              7226
# 5              7122
# 6              7344
# 10             6808
# 11             6461

# %%
stock_price_pl =  ((result['price']).sum() * 0.7 * 0.8 * 0.9 / result['weight'].sum()).round(0)
print('Средняя цена остатков офлайн ПЛ: ', stock_price_pl)
# Out:
# Средняя цена остатков офлайн ПЛ:  6724.0

# %%
date_now = dt.datetime.now().date().strftime('%d.%m.%Y')

# %%
result.to_excel(rf'\\gold585.int\uk\Общее хранилище файлов\Служба аналитики\Тренкин Сергей\stock_offline\zolotoy_stock_offline_{date_now}.xlsx', index=False)

# %%
result = result.drop(columns=['price', 'weight', 'cost_price', 'margin'])

# %%
result.columns = ['tg', '585*Золотой оффлайн остатки 20% + 30%']

# %%
result
# Out:
#                  tg  585*Золотой оффлайн остатки 20% + 30%
# 1         БК КОЛЬЦА                                   6817
# 2   БК КОЛЬЦА ОБРУЧ                                   6636
# 4   БК ПОДВЕС ДЕКОР                                   7226
# 5   БК ПОДВЕС КУЛЬТ                                   7122
# 6         БК СЕРЬГИ                                   7344
# 10      ЦБ БРАСЛЕТЫ                                   6808
# 11          ЦБ ЦЕПИ                                   6461

# %%
# здесь соединяется между собой файл, формирующий итоговую разбивку по цене за грамм золота
# первым формируется файл по Sokolov и Sunlight после парсинга данных и обработки их в ноутбуке eda_data_for_dash.ipynb 
pd.read_excel(rf'\\gold585.int\uk\Общее хранилище файлов\Служба аналитики\Тренкин Сергей\sklv_sl_data\grouped_data\result_{date_now}.xlsx').merge(result, how = 'left', on = 'tg').to_excel(rf'\\gold585.int\uk\Общее хранилище файлов\Служба аналитики\Тренкин Сергей\sklv_sl_data\grouped_data\result_{date_now}.xlsx', index=False)
