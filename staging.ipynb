# %%
from sqlalchemy import create_engine, text
from bs4 import BeautifulSoup as bs
import datetime as dt
import pandas as pd
import numpy as np
import warnings
import requests
import pymssql
import locale
import glob
import os

warnings.filterwarnings('ignore')
pd.set_option('use_inf_as_na', True)
pd.options.display.max_columns = None
pd.set_option('float_format', '{:.2f}'.format)
locale.setlocale(locale.LC_ALL, 'ru_RU.UTF-8')
# Out:
# 'ru_RU.UTF-8'

# %%
conn = pymssql.connect(server='AX-SQL', database='Staging')
cursor = conn.cursor()

sql = f'''
SELECT [Код склада], [Название склада], [Название товара], [Артикул поставщика], [Остаток], 
[Проба], [Чистый вес], [Товарное направление], [Товарная группа], [Тип изделия 1], [Тип изделия 2],
[Тип изделия 3], [Группа цен], [Скидка на изделии], [Запрет скидки], [Дизайн], [Бренд], [Дата закупки], 
[Цена Розн., за шт], [Гендерный признак], [Ценовая корзина], [Товарный кластер], [Внутренний артикул],
[ID Сайта], [Цена Закупки за 1 шт. (упр сс с НДС за единицу)]
from [Staging].[Reports].[Remainings_8h]
where [Товарное направление] in (N'БК', N'ЦБ', N'СИ', N'ИФ', N'ПДК', N'ДК', N'ВЫРИЦА', N'ЧАСЫ')
'''

sql_query = pd.read_sql_query(sql, conn)
stock = pd.DataFrame(sql_query)

# %%
conn = pymssql.connect(server='AX-SQL', database='Staging')
cursor = conn.cursor()

sql = f'''
SELECT [Код склада], [Название склада], [Название товара], [Артикул поставщика], [Остаток], 
[Проба], [Чистый вес], [Товарное направление], [Товарная группа], [Тип изделия 1], [Тип изделия 2],
[Тип изделия 3], [Группа цен], [Скидка на изделии], [Запрет скидки], [Дизайн], [Бренд], [Дата закупки], 
[Цена Розн., за шт], [Гендерный признак], [Ценовая корзина], [Товарный кластер], [Внутренний артикул],
[ID Сайта], [Цена Закупки за 1 шт. (упр сс с НДС за единицу)]
from [Staging].[Reports].[Remainings_8h]
where [Товарное направление] in (N'БК', N'ЦБ', N'СИ', N'ИФ', N'ПДК', N'ДК', N'ВЫРИЦА', N'ЧАСЫ')
'''

sql_query = pd.read_sql_query(sql, conn)
stock = pd.DataFrame(sql_query)

# %%
df = stock

# %%
ids = df.groupby(by = 'Артикул поставщика', as_index=False)['Остаток'].sum()

# %%
ids = ids.query('Остаток >= 50')

# %%
df.columns
# Out:
# Index(['Код склада', 'Название склада', 'Название товара',
#        'Артикул поставщика', 'Остаток', 'Проба', 'Чистый вес',
#        'Товарное направление', 'Товарная группа', 'Тип изделия 1',
#        'Тип изделия 2', 'Тип изделия 3', 'Группа цен', 'Скидка на изделии',
#        'Запрет скидки', 'Дизайн', 'Бренд', 'Дата закупки', 'Цена Розн., за шт',
#        'Гендерный признак', 'Ценовая корзина', 'Товарный кластер',
#        'Внутренний артикул', 'ID Сайта',
#        'Цена Закупки за 1 шт. (упр сс с НДС за единицу)'],
#       dtype='object')

# %%
idss = df[['Код склада', 'Название склада', 'Название товара',
    'Артикул поставщика', 'Остаток', 'Проба', 'Чистый вес',
    'Товарное направление', 'Товарная группа', 'Тип изделия 1',
    'Тип изделия 2', 'Тип изделия 3', 'Группа цен', 'Скидка на изделии',
    'Запрет скидки', 'Дизайн', 'Бренд', 'Дата закупки', 'Цена Розн., за шт',
    'Гендерный признак', 'Ценовая корзина', 'Товарный кластер',
    'Внутренний артикул', 'ID Сайта',
    'Цена Закупки за 1 шт. (упр сс с НДС за единицу)']]

# %%
# stock.to_csv(r'C:\Users\Trenkin.Sergey\Desktop\sales\\выгрузка.csv', index=False)

# %%
ids = idss.merge(ids, how='left', on='Артикул поставщика')

# %%
ids = ids.drop_duplicates(subset=['Артикул поставщика'])

# %%
ids = ids.query('Остаток_y >= 50')

# %%
ids = ids[~ids['Товарное направление'].str.contains('ФУТЛЯРЫ|БУ')]
ids = ids[ids['Проба'].str.contains('585|925')]

# %%
ids['Товарное направление'].unique().tolist()
# Out:
# ['ЦБ', 'ИФ', 'ДК', 'СИ', 'БК', 'ПДК', 'ВЫРИЦА', 'ЧАСЫ']

# %%
ids['Проба'].value_counts()
# Out:
# Проба
# 585    11621
# 925     8677
# Name: count, dtype: int64

# %%
stock['Товарное направление'].value_counts(dropna=False)
# Out:
# Товарное направление
# СИ        2767247
# ИФ         905050
# БК         839826
# ЦБ         647023
# ПДК        601238
# ДК         569084
# ВЫРИЦА      85064
# ЧАСЫ        76767
# Name: count, dtype: int64

# %%
sales_may1 = pd.read_excel(r'\\gold585.int\uk\Общее хранилище файлов\Служба аналитики\Выгрузки из DWH\Продажи по КБК из DWH new\2024-05-01_2024-05-09.xlsx')
sales_may2 = pd.read_excel(r'\\gold585.int\uk\Общее хранилище файлов\Служба аналитики\Выгрузки из DWH\Продажи по КБК из DWH new\2024-05-10_2024-05-19.xlsx')
sales_may3 = pd.read_excel(r'C:\Users\Trenkin.Sergey\Desktop\Книга13.xlsx')

# %%
sales_may3['Артикул поставщика'] = sales_may3['Артикул поставщика'].astype(str)

# %%
sales_may = pd.concat([sales_may1, sales_may2, sales_may3], ignore_index=True)

# %%
articles = ids['Артикул поставщика'].tolist()
arts = ids['ID Сайта'].tolist()

# %%
sales_may = sales_may.dropna(subset=['Количество', 'Артикул поставщика'])

# %%
sales_may['Количество'].value_counts(dropna=False)
# Out:
# Количество
# 1.00     724985
# -1.00      3503
# Name: count, dtype: int64

# %%
sales_may = sales_may.groupby(by = 'Артикул поставщика', as_index=False)[['Количество']].sum()

# %%
sales_may.columns = ['article', 'count']

# %%
sales_may = sales_may.query('article in @articles')

# %%
sales_may.columns = ['Артикул поставщика', 'Количество']
sales_may
# Out:
#       Артикул поставщика  Количество
# 6                  0-017       56.00
# 11            00-03-0858        7.00
# 13                 00008        9.00
# 16           000094-0#ХХ        3.00
# 19                00016Ч        7.00
# ...                  ...         ...
# 41708       с300-1156НЕФ       10.00
# 41709             с35-04       37.00
# 41710            с462-20        2.00
# 41711              с9-16       35.00
# 41712              ск010       27.00
#
# [17000 rows x 2 columns]

# %%
ids = ids.merge(sales_may, how='left', on='Артикул поставщика')

# %%
ids['Количество'].value_counts()
# Out:
# Количество
# 1.00      2995
# 2.00      2421
# 3.00      1734
# 4.00      1378
# 5.00       992
#           ...
# 333.00       1
# 171.00       1
# 423.00       1
# 289.00       1
# 558.00       1
# Name: count, Length: 331, dtype: int64

# %%
ids.to_excel('result.xlsx', index=False)

# %%
images = pd.read_excel(r'C:\Users\Trenkin.Sergey\Desktop\Артикул-фото 2024.06.11_.xlsx')

# %%
images = images.drop_duplicates(subset = ['article'])

# %%
images['article'] = images['article'].astype(str)

# %%
images = images.query('article in @arts')

# %%
images
# Out:
#         article  sort  published  \
# 2       1000091     3       True
# 5       1000181     1       True
# 6       1000188     3       True
# 16      1000339     1       True
# 19      1000477     1       True
# ...         ...   ...        ...
# 181631  8380093     4       True
# 181637  8380097     5       True
# 181642  8380099     4       True
# 181646  8380101     4       True
# 181650  8380103     4       True
#
#                                     Ссылка на изображение  \
# 2       https://static2.585.cloud/media/products/f2d30...
# 5       https://static2.585.cloud/media/products/38b3b...
# 6       https://static2.585.cloud/media/products/f3bf4...
# 16      https://static2.585.cloud/media/products/b141d...
# 19      https://static2.585.cloud/media/products/b1000...
# ...                                                   ...
# 181631  https://static2.585.cloud/media/products/99ab5...
# 181637  https://static2.585.cloud/media/products/a3245...
# 181642  https://static2.585.cloud/media/products/ffa1a...
# 181646  https://static2.585.cloud/media/products/1c202...
# 181650  https://static2.585.cloud/media/products/2246c...
#
#                                           Ссылка на товар
# 2       https://www.585zolotoy.ru/catalog/products/100...
# 5       https://www.585zolotoy.ru/catalog/products/100...
# 6       https://www.585zolotoy.ru/catalog/products/100...
# 16      https://www.585zolotoy.ru/catalog/products/100...
# 19      https://www.585zolotoy.ru/catalog/products/100...
# ...                                                   ...
# 181631  https://www.585zolotoy.ru/catalog/products/838...
# 181637  https://www.585zolotoy.ru/catalog/products/838...
# 181642  https://www.585zolotoy.ru/catalog/products/838...
# 181646  https://www.585zolotoy.ru/catalog/products/838...
# 181650  https://www.585zolotoy.ru/catalog/products/838...
#
# [16359 rows x 5 columns]

# %%
images = images[['article', 'Ссылка на изображение', 'published']]

# %%
ids
# Out:
#       Код склада                Название склада  \
# 0           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 1           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 2           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 3           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 4           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# ...          ...                            ...
# 20293       3075  Центральный склад Регент Голд
# 20294       3075  Центральный склад Регент Голд
# 20295       3075  Центральный склад Регент Голд
# 20296       3075  Центральный склад Регент Голд
# 20297       3075  Центральный склад Регент Голд
#
#                                        Название товара   Артикул поставщика  \
# 0                                 Браслет Веревка пуст    431-00-0060-30333
# 1                      Браслет Ромб двойной пуст с а/г    411-01-0035-30176
# 2                                      Серьги, фианит               1241689
# 3                        серьги с бриллиантом с родир.       2436-151-00-00
# 4                                          Подвес род.            2035076/9
# ...                                                ...                  ...
# 20293           Кольцо с бриллиантами выращ., с родир.     20-12-Ф000-13341
# 20294                       Подвес икона Семистрельная     52-0Z-0000-13522
# 20295                                           Подвес  50-00-0000-13608#ER
# 20296         Подвес позолота, культивированный жемчуг               18.104
# 20297  Кольцо с бриллиантами+шайба+алм.грань, с родир.     20-33-1000-13349
#
#        Остаток_x Проба  Чистый вес Товарное направление  Товарная группа  \
# 0           1.00   585        2.09                   ЦБ      ЦБ БРАСЛЕТЫ
# 1           1.00   585        0.65                   ЦБ      ЦБ БРАСЛЕТЫ
# 2           1.00   585        1.98                   ИФ        ИФ СЕРЬГИ
# 3           1.00   585        3.06                   ДК        ДК СЕРЬГИ
# 4           1.00   925        0.50                   СИ     СИ ПОДВЕС БК
# ...          ...   ...         ...                  ...              ...
# 20293       1.00   585        1.09                   ДК        ДК КОЛЬЦА
# 20294       1.00   585        1.19                   БК  БК ПОДВЕС КУЛЬТ
# 20295       1.00   585        1.09                   БК  БК ПОДВЕС ДЕКОР
# 20296       1.00   925        2.30               ВЫРИЦА   ВЫРИЦА СЕРЕБРО
# 20297       1.00   585        1.29                   ДК        ДК КОЛЬЦА
#
#              Тип изделия 1             Тип изделия 2         Тип изделия 3  \
# 0                  БРАСЛЕТ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 1                  БРАСЛЕТ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 2                   СЕРЬГИ               С ФИАНИТАМИ               КРАСНЫЙ
# 3                   СЕРЬГИ    С ДРАГОЦЕННЫМИ КАМНЯМИ               КРАСНЫЙ
# 4      ПОДВЕС ДЕКОРАТИВНЫЙ                БЕЗ КАМНЕЙ  БЕЛЫЙ С РОДИРОВАНИЕМ
# ...                    ...                       ...                   ...
# 20293               КОЛЬЦО  С ИСКУССТВЕННЫМИ КАМНЯМИ                 БЕЛЫЙ
# 20294     ПОДВЕС КУЛЬТОВЫЙ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 20295  ПОДВЕС ДЕКОРАТИВНЫЙ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 20296               ПОДВЕС                С ЖЕМЧУГОМ                ЖЕЛТЫЙ
# 20297               КОЛЬЦО    С ДРАГОЦЕННЫМИ КАМНЯМИ               КРАСНЫЙ
#
#                           Группа цен  Скидка на изделии Запрет скидки  \
# 0      ЦБ_ЮИТ_ПУСТОТЕЛЫЕ_КОРДА <3 ГР              25.00           Нет
# 1          ЦБ_ПУСТОТЕЛЫЕ <=1,5 ГРАММ              30.00           Нет
# 2                           ИФ.БК_СР              34.00           Нет
# 3                         ДК_СРЕДНЯЯ              66.00           Нет
# 4              СИ_ПОДВЕС_ДЕКОР_СРЕДН              40.00           Нет
# ...                              ...                ...           ...
# 20293                     ДК_ДОРОГАЯ               0.00           Нет
# 20294                      ИФ.БК_ДЕШ               0.00           Нет
# 20295                       ИФ.БК_СР               0.00           Нет
# 20296                  СИ_ВЫРИЦА_ДЕШ               0.00           Нет
# 20297                     ДК_СРЕДНЯЯ               0.00           Нет
#
#                   Дизайн                  Бренд Дата закупки  \
# 0           ВЕРЕВКА ПУСТ  Значение по умолчанию   2023-02-15
# 1      РОМБ ДВОЙНОЙ ПУСТ              ADRIATICA   2023-04-12
# 2      ИФ С ОДНИМ КАМНЕМ  Значение по умолчанию   2023-11-30
# 3      ДК С ОДНИМ КАМНЕМ  Значение по умолчанию         None
# 4              СИ ПРОЧЕЕ  Значение по умолчанию   2024-02-16
# ...                  ...                    ...          ...
# 20293    ДК МНОГОКАМЕНКА  Значение по умолчанию   2024-06-11
# 20294           ИФ ИКОНА  Значение по умолчанию   2024-06-08
# 20295          ИФ ПРОЧЕЕ  Значение по умолчанию   2024-06-08
# 20296           В_ПРОЧЕЕ                 ВЫРИЦА   2024-06-11
# 20297       ДК ГЕОМЕТРИЯ  Значение по умолчанию   2024-06-11
#
#        Цена Розн., за шт      Гендерный признак Ценовая корзина  \
# 0               34970.00                женские         ДЕШЕВАЯ
# 1               12513.00                женские         ДЕШЕВАЯ
# 2               39382.00                женские         СРЕДНЯЯ
# 3              163994.00                женские         СРЕДНЯЯ
# 4                1150.00                женские        ЛЕГКОВЕС
# ...                  ...                    ...             ...
# 20293                NaN                женские         ДОРОГАЯ
# 20294                NaN                унисекс         ДЕШЕВАЯ
# 20295                NaN                Унисекс         СРЕДНЯЯ
# 20296                NaN  Значение по умолчанию         СРЕДНЯЯ
# 20297                NaN                женские         СРЕДНЯЯ
#
#       Товарный кластер      Внутренний артикул ID Сайта  \
# 0              7645_ЦБ    431-00-0060-30333_ЦБ  3778045
# 1              7730_ЦБ    411-01-0035-30176_ЦБ  1674395
# 2              ИФ_1044              1241689_ИФ  2735473
# 3              ДК_2090       2436-151-00-00_ДК  4058155
# 4              6400_СИ            2035076/9_СИ  3558970
# ...                ...                     ...      ...
# 20293          ДК_2027    20-12-Ф000-13341 _ДК
# 20294          БК_1568     52-0Z-0000-13522_БК
# 20295          БК_1593  50-00-0000-13608#ER_БК
# 20296                            18.104_ВЫРИЦА
# 20297          ДК_2020     20-33-1000-13349_ДК
#
#        Цена Закупки за 1 шт. (упр сс с НДС за единицу)  Остаток_y  Количество
# 0                                              4782.59    3501.00      140.00
# 1                                              1436.74    2635.00      147.00
# 2                                              6802.13     506.00       25.00
# 3                                             10755.11     334.00        7.00
# 4                                               195.00    1088.00      131.00
# ...                                                ...        ...         ...
# 20293                                         24924.21      95.00         NaN
# 20294                                          4197.12      50.00         NaN
# 20295                                          3980.90      55.00         NaN
# 20296                                          1912.00     101.00         NaN
# 20297                                          7314.37      99.00         NaN
#
# [20298 rows x 27 columns]

# %%
images.columns = ['ID Сайта', 'Ссылка на изображение', 'published']

# %%
ids = ids.merge(images, how='left', on='ID Сайта')

# %%
ids.columns
# Out:
# Index(['Код склада', 'Название склада', 'Название товара',
#        'Артикул поставщика', 'Остаток_x', 'Проба', 'Чистый вес',
#        'Товарное направление', 'Товарная группа', 'Тип изделия 1',
#        'Тип изделия 2', 'Тип изделия 3', 'Группа цен', 'Скидка на изделии',
#        'Запрет скидки', 'Дизайн', 'Бренд', 'Дата закупки', 'Цена Розн., за шт',
#        'Гендерный признак', 'Ценовая корзина', 'Товарный кластер',
#        'Внутренний артикул', 'ID Сайта',
#        'Цена Закупки за 1 шт. (упр сс с НДС за единицу)', 'Остаток_y',
#        'Количество', 'Ссылка на изображение', 'published'],
#       dtype='object')

# %%
ids.columns = ['Код склада', 'Название склада', 'Название товара',
    'Артикул поставщика', 'Остаток_x', 'Проба', 'Чистый вес',
    'Товарное направление', 'Товарная группа', 'Тип изделия 1',
    'Тип изделия 2', 'Тип изделия 3', 'Группа цен', 'Скидка на изделии',
    'Запрет скидки', 'Дизайн', 'Бренд', 'Дата закупки', 'Цена Розн., за шт',
    'Гендерный признак', 'Ценовая корзина', 'Товарный кластер',
    'Внутренний артикул', 'ID Сайта',
    'Цена Закупки за 1 шт. (упр сс с НДС за единицу)', 'Остаток_y',
    'Количество продаж за май', 'Ссылка на изображение', 'published']

# %%
ids['Товарная группа'].unique().tolist()
# Out:
# ['ЦБ БРАСЛЕТЫ',
#  'ИФ СЕРЬГИ',
#  'ДК СЕРЬГИ',
#  'СИ ПОДВЕС БК',
#  'СИ СЕРЬГИ\xa0 ЦВ/К',
#  'СИ ЖЕМЧУГ',
#  'ИФ КОЛЬЦА',
#  'СИ ПОДВЕС\xa0ЦВ/К',
#  'СИ БРАСЛЕТ БК',
#  'БК КОЛЬЦА ОБРУЧ',
#  'СИ СЕРЬГИ РАЗН',
#  'СИ КОЛЬЦО ЦВ/К',
#  'СИ КОЛЬЦО БК',
#  'ПДК СЕРЬГИ',
#  'СИ ЦЕПЬ',
#  'СИ КЕРАМИКА',
#  'ИФ ПОДВЕС ДЕКОР',
#  'СИ ПОДВЕС ИФ',
#  'БК ПОДВЕС КУЛЬТ',
#  'ДК ПОДВЕСКИ',
#  'ЦБ ЦЕПИ',
#  'ПДК КОЛЬЦА',
#  'СИ ШАРМЫ',
#  'СИ КОЛЬЦО ИФ',
#  'ДК КОЛЬЦА ОБРУЧ',
#  'БК ПОДВЕС ДЕКОР',
#  'СИ ОБРУЧАЛЬНОЕ',
#  'СИ СЕРЬГИ БК',
#  'СИ КОЛЬЕ ЦВ/К',
#  'СИ КОЛЬЕ СК',
#  'СИ БРАСЛЕТ СК',
#  'БК КОЛЬЦА',
#  'ДК КОЛЬЦА',
#  'ИФ ПОДВЕС КУЛЬТ',
#  'СИ АКСЕССУАР',
#  'ПДК ПОДВЕСКИ',
#  'СИ ПОДАРКИ КРОСС',
#  'СИ СЕРЬГИ ИФ',
#  'БК СЕРЬГИ',
#  'ИФ КОЛЬЦА ОБРУЧ',
#  'СИ КОЛЬЕ С ЭМАЛЬЮ',
#  'ОПТ БК',
#  'БК ПЕЧАТКИ',
#  'ПДК ПЕЧАТКИ',
#  'СИ КОЛЬЦО ПЕЧАТ',
#  'СИ КОЛЬЕ БК',
#  'ДК ПЕЧАТКИ',
#  'ИФ ПЕЧАТКИ',
#  'СИ БРАСЛЕТ ЦВ/К',
#  'ВЫРИЦА СЕРЕБРО',
#  'ОПТ ИФ',
#  'ЧАСЫ',
#  'СИ БРАСЛЕТ БК Декор',
#  'СИ ЭМАЛЬ',
#  'ОПТ ПДК',
#  'СИ ЯНТАРЬ',
#  'СИ ПОСУДА',
#  'ВЫРИЦА ЗОЛОТО',
#  'ОПТ КОНГО',
#  'ОПТ ОБРУЧИ',
#  'БК АКСЕССУАРЫ',
#  'ИФ АКСЕССУАРЫ']

# %%
ids = ids[~ids['Товарная группа'].str.contains('АКСЕССУАР|ОПТ|ПОСУДА|КРОСС|ЦВ/К|РАЗН|КЕРАМИКА|ЭМАЛЬ|ЯНТАРЬ')]

# %%
ids = ids.drop(columns=['Остаток_x'])

# %%
ids
# Out:
#       Код склада                Название склада  \
# 0           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 1           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 2           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 3           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 4           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# ...          ...                            ...
# 20293       3075  Центральный склад Регент Голд
# 20294       3075  Центральный склад Регент Голд
# 20295       3075  Центральный склад Регент Голд
# 20296       3075  Центральный склад Регент Голд
# 20297       3075  Центральный склад Регент Голд
#
#                                        Название товара   Артикул поставщика  \
# 0                                 Браслет Веревка пуст    431-00-0060-30333
# 1                      Браслет Ромб двойной пуст с а/г    411-01-0035-30176
# 2                                      Серьги, фианит               1241689
# 3                        серьги с бриллиантом с родир.       2436-151-00-00
# 4                                          Подвес род.            2035076/9
# ...                                                ...                  ...
# 20293           Кольцо с бриллиантами выращ., с родир.     20-12-Ф000-13341
# 20294                       Подвес икона Семистрельная     52-0Z-0000-13522
# 20295                                           Подвес  50-00-0000-13608#ER
# 20296         Подвес позолота, культивированный жемчуг               18.104
# 20297  Кольцо с бриллиантами+шайба+алм.грань, с родир.     20-33-1000-13349
#
#       Проба  Чистый вес Товарное направление  Товарная группа  \
# 0       585        2.09                   ЦБ      ЦБ БРАСЛЕТЫ
# 1       585        0.65                   ЦБ      ЦБ БРАСЛЕТЫ
# 2       585        1.98                   ИФ        ИФ СЕРЬГИ
# 3       585        3.06                   ДК        ДК СЕРЬГИ
# 4       925        0.50                   СИ     СИ ПОДВЕС БК
# ...     ...         ...                  ...              ...
# 20293   585        1.09                   ДК        ДК КОЛЬЦА
# 20294   585        1.19                   БК  БК ПОДВЕС КУЛЬТ
# 20295   585        1.09                   БК  БК ПОДВЕС ДЕКОР
# 20296   925        2.30               ВЫРИЦА   ВЫРИЦА СЕРЕБРО
# 20297   585        1.29                   ДК        ДК КОЛЬЦА
#
#              Тип изделия 1             Тип изделия 2         Тип изделия 3  \
# 0                  БРАСЛЕТ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 1                  БРАСЛЕТ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 2                   СЕРЬГИ               С ФИАНИТАМИ               КРАСНЫЙ
# 3                   СЕРЬГИ    С ДРАГОЦЕННЫМИ КАМНЯМИ               КРАСНЫЙ
# 4      ПОДВЕС ДЕКОРАТИВНЫЙ                БЕЗ КАМНЕЙ  БЕЛЫЙ С РОДИРОВАНИЕМ
# ...                    ...                       ...                   ...
# 20293               КОЛЬЦО  С ИСКУССТВЕННЫМИ КАМНЯМИ                 БЕЛЫЙ
# 20294     ПОДВЕС КУЛЬТОВЫЙ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 20295  ПОДВЕС ДЕКОРАТИВНЫЙ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 20296               ПОДВЕС                С ЖЕМЧУГОМ                ЖЕЛТЫЙ
# 20297               КОЛЬЦО    С ДРАГОЦЕННЫМИ КАМНЯМИ               КРАСНЫЙ
#
#                           Группа цен  Скидка на изделии Запрет скидки  \
# 0      ЦБ_ЮИТ_ПУСТОТЕЛЫЕ_КОРДА <3 ГР              25.00           Нет
# 1          ЦБ_ПУСТОТЕЛЫЕ <=1,5 ГРАММ              30.00           Нет
# 2                           ИФ.БК_СР              34.00           Нет
# 3                         ДК_СРЕДНЯЯ              66.00           Нет
# 4              СИ_ПОДВЕС_ДЕКОР_СРЕДН              40.00           Нет
# ...                              ...                ...           ...
# 20293                     ДК_ДОРОГАЯ               0.00           Нет
# 20294                      ИФ.БК_ДЕШ               0.00           Нет
# 20295                       ИФ.БК_СР               0.00           Нет
# 20296                  СИ_ВЫРИЦА_ДЕШ               0.00           Нет
# 20297                     ДК_СРЕДНЯЯ               0.00           Нет
#
#                   Дизайн                  Бренд Дата закупки  \
# 0           ВЕРЕВКА ПУСТ  Значение по умолчанию   2023-02-15
# 1      РОМБ ДВОЙНОЙ ПУСТ              ADRIATICA   2023-04-12
# 2      ИФ С ОДНИМ КАМНЕМ  Значение по умолчанию   2023-11-30
# 3      ДК С ОДНИМ КАМНЕМ  Значение по умолчанию         None
# 4              СИ ПРОЧЕЕ  Значение по умолчанию   2024-02-16
# ...                  ...                    ...          ...
# 20293    ДК МНОГОКАМЕНКА  Значение по умолчанию   2024-06-11
# 20294           ИФ ИКОНА  Значение по умолчанию   2024-06-08
# 20295          ИФ ПРОЧЕЕ  Значение по умолчанию   2024-06-08
# 20296           В_ПРОЧЕЕ                 ВЫРИЦА   2024-06-11
# 20297       ДК ГЕОМЕТРИЯ  Значение по умолчанию   2024-06-11
#
#        Цена Розн., за шт      Гендерный признак Ценовая корзина  \
# 0               34970.00                женские         ДЕШЕВАЯ
# 1               12513.00                женские         ДЕШЕВАЯ
# 2               39382.00                женские         СРЕДНЯЯ
# 3              163994.00                женские         СРЕДНЯЯ
# 4                1150.00                женские        ЛЕГКОВЕС
# ...                  ...                    ...             ...
# 20293                NaN                женские         ДОРОГАЯ
# 20294                NaN                унисекс         ДЕШЕВАЯ
# 20295                NaN                Унисекс         СРЕДНЯЯ
# 20296                NaN  Значение по умолчанию         СРЕДНЯЯ
# 20297                NaN                женские         СРЕДНЯЯ
#
#       Товарный кластер      Внутренний артикул ID Сайта  \
# 0              7645_ЦБ    431-00-0060-30333_ЦБ  3778045
# 1              7730_ЦБ    411-01-0035-30176_ЦБ  1674395
# 2              ИФ_1044              1241689_ИФ  2735473
# 3              ДК_2090       2436-151-00-00_ДК  4058155
# 4              6400_СИ            2035076/9_СИ  3558970
# ...                ...                     ...      ...
# 20293          ДК_2027    20-12-Ф000-13341 _ДК
# 20294          БК_1568     52-0Z-0000-13522_БК
# 20295          БК_1593  50-00-0000-13608#ER_БК
# 20296                            18.104_ВЫРИЦА
# 20297          ДК_2020     20-33-1000-13349_ДК
#
#        Цена Закупки за 1 шт. (упр сс с НДС за единицу)  Остаток_y  \
# 0                                              4782.59    3501.00
# 1                                              1436.74    2635.00
# 2                                              6802.13     506.00
# 3                                             10755.11     334.00
# 4                                               195.00    1088.00
# ...                                                ...        ...
# 20293                                         24924.21      95.00
# 20294                                          4197.12      50.00
# 20295                                          3980.90      55.00
# 20296                                          1912.00     101.00
# 20297                                          7314.37      99.00
#
#        Количество продаж за май  \
# 0                        140.00
# 1                        147.00
# 2                         25.00
# 3                          7.00
# 4                        131.00
# ...                         ...
# 20293                       NaN
# 20294                       NaN
# 20295                       NaN
# 20296                       NaN
# 20297                       NaN
#
#                                    Ссылка на изображение published  \
# 0      https://static2.585.cloud/media/products/d5758...      True
# 1      https://static2.585.cloud/media/products/6bedb...      True
# 2      https://static2.585.cloud/media/products/ff494...      True
# 3      https://static2.585.cloud/media/products/501d7...      True
# 4      https://static2.585.cloud/media/products/21c90...      True
# ...                                                  ...       ...
# 20293                                                NaN       NaN
# 20294                                                NaN       NaN
# 20295                                                NaN       NaN
# 20296                                                NaN       NaN
# 20297                                                NaN       NaN
#
#        price_personal
# 0            12589.20
# 1             4204.37
# 2            12476.22
# 3            26763.82
# 4              331.20
# ...               ...
# 20293             NaN
# 20294             NaN
# 20295             NaN
# 20296             NaN
# 20297             NaN
#
# [17363 rows x 29 columns]

# %%
ids['price_personal'] = np.where(
    ids['Запрет скидки'] == 'Да', ids['Цена Розн., за шт'], 
    np.where(
        ids['Проба'] == 925, ids['Цена Розн., за шт'] * 0.7 * 0.8 * (1 - (ids['Скидка на изделии'] / 100)), ids['Цена Розн., за шт'] * 0.6 * 0.8 * (1 - (ids['Скидка на изделии'] / 100))
    )
)

# %%
ids['Наценка'] = ids['price_personal'] / ids['Цена Закупки за 1 шт. (упр сс с НДС за единицу)'] - 1

# %%
ids.columns
# Out:
# Index(['Код склада', 'Название склада', 'Название товара',
#        'Артикул поставщика', 'Проба', 'Чистый вес', 'Товарное направление',
#        'Товарная группа', 'Тип изделия 1', 'Тип изделия 2', 'Тип изделия 3',
#        'Группа цен', 'Скидка на изделии', 'Запрет скидки', 'Дизайн', 'Бренд',
#        'Дата закупки', 'Цена Розн., за шт', 'Гендерный признак',
#        'Ценовая корзина', 'Товарный кластер', 'Внутренний артикул', 'ID Сайта',
#        'Цена Закупки за 1 шт. (упр сс с НДС за единицу)', 'Остаток_y',
#        'Количество продаж за май', 'Ссылка на изображение', 'published',
#        'price_personal', 'Наценка'],
#       dtype='object')

# %%
ids.columns = ['Код склада', 'Название склада', 'Название товара',
    'Артикул поставщика', 'Проба', 'Чистый вес', 'Товарное направление',
    'Товарная группа', 'Тип изделия 1', 'Тип изделия 2', 'Тип изделия 3',
    'Группа цен', 'Скидка на изделии', 'Запрет скидки', 'Дизайн', 'Бренд',
    'Дата закупки', 'Цена Розн., за шт', 'Гендерный признак',
    'Ценовая корзина', 'Товарный кластер', 'Внутренний артикул', 'ID Сайта',
    'Себестоимость', 'Остаток',
    'Количество продаж за май', 'Ссылка на изображение', 'published',
    'Итоговая цена на изделии', 'Наценка']

# %%
stock['Дата закупки'] = pd.to_datetime(stock['Дата закупки'], dayfirst=True)

# %%
min_date = stock.groupby(by = 'Артикул поставщика', as_index=False)['Дата закупки'].min()

# %%
min_date.columns = ['article', 'date']

# %%
articles = df['Артикул поставщика'].tolist()

# %%
min_date = min_date.query('article in @articles')

# %%
min_date.columns = ['Артикул поставщика', 'Дата закупки']

# %%
ids = ids.drop(columns=['Дата закупки'])

# %%
ids = ids.merge(min_date, how='left', on='Артикул поставщика')

# %%
os.chdir(r'C:\\Users\Trenkin.Sergey\Desktop\sales')
extension = 'xlsx'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
all_filenames
# Out:
# ['2024-03-10_2024-03-19.xlsx',
#  '2024-03-20_2024-03-31.xlsx',
#  '2024-04-01_2024-04-09.xlsx',
#  '2024-04-10_2024-04-19.xlsx',
#  '2024-04-20_2024-04-30.xlsx',
#  '2024-05-01_2024-05-09.xlsx',
#  '2024-05-10_2024-05-19.xlsx',
#  '2024-06-01_2024-06-09.xlsx',
#  '2024-06-10_2024-06-10.xlsx',
#  '2024-06-10_2024-06-12.xlsx']

# %%
sale = pd.DataFrame()
for name in all_filenames:
    sales = pd.read_excel(name)
    sale = pd.concat([sales, sale], ignore_index= True)

# %%
sale['Дата'] = pd.to_datetime(sale['Дата'], dayfirst=True, format='mixed')

# %%
sale = sale[(sale['Дата'] >= pd.to_datetime('2024-03-14', dayfirst=True, format='mixed')) & 
            (sale['Дата'] <= pd.to_datetime('2024-06-11', dayfirst=True, format='mixed'))]

# %%
sale.columns = ['КБК', 'Дата', 'Продавец', 'Номер чека', 'ID продажи', 'Тов',
    'article', 'Количество', 'Номенклатура', 'Номер карты',
    'Товарная группа', 'Товарное направление', 'Тип 1',
    'Списание СберСпасибо', 'Группа наценки', 'Вес', 'Проба', 'Размер',
    'ШК', 'Цена без скидки', 'Базовая скидка', 'Скидка в руб.', 'Название',
    'Цена после скидки', 'Phone', 'Себестоимость', 'Сумма', 'Услуга',
    'Общая сумма']

# %%
sale = sale.query('article in @articles')

# %%
sale = sale.groupby(by = 'article', as_index=False)[['Количество', 'Общая сумма']].sum()

# %%
sale.columns = ['Артикул поставщика', 'Количество продаж', 'Общая сумма продаж']

# %%
ids = ids.merge(sale, how='left', on='Артикул поставщика')

# %%
ids.columns
# Out:
# Index(['Код склада', 'Название склада', 'Название товара',
#        'Артикул поставщика', 'Проба', 'Чистый вес', 'Товарное направление',
#        'Товарная группа', 'Тип изделия 1', 'Тип изделия 2', 'Тип изделия 3',
#        'Группа цен', 'Скидка на изделии', 'Запрет скидки', 'Дизайн', 'Бренд',
#        'Цена Розн., за шт', 'Гендерный признак', 'Ценовая корзина',
#        'Товарный кластер', 'Внутренний артикул', 'ID Сайта', 'Себестоимость',
#        'Остаток', 'Количество продаж за май', 'Ссылка на изображение',
#        'published', 'Итоговая цена на изделии', 'Наценка', 'Дата закупки',
#        'Количество продаж', 'Общая сумма продаж'],
#       dtype='object')

# %%
ids.columns = ['Код склада', 'Название склада', 'Название товара',
    'Артикул поставщика', 'Проба', 'Чистый вес', 'Товарное направление',
    'Товарная группа', 'Тип изделия 1', 'Тип изделия 2', 'Тип изделия 3',
    'Группа цен', 'Скидка на изделии', 'Запрет скидки', 'Дизайн', 'Бренд',
    'Цена Розн., за шт', 'Гендерный признак', 'Ценовая корзина',
    'Товарный кластер', 'Внутренний артикул', 'ID Сайта', 'Себестоимость',
    'Остаток', 'Количество продаж за май', 'Ссылка на изображение',
    'published', 'Итоговая цена на изделии', 'Наценка', 'Минимальная дата закупки', 'Количество продаж 14.03-11.06', 'Общая сумма продаж 14.03-11.06']

# %%
stock
# Out:
#         Код склада                                    Название склада  \
# 0             4616                       Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 1             4616                       Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 2             4616                       Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 3             4616                       Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 4             4616                       Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# ...            ...                                                ...
# 6491294       3963  Ярославль, пос.Нагорный, Дорожная, 6а, ТРК «Яр...
# 6491295       3963  Ярославль, пос.Нагорный, Дорожная, 6а, ТРК «Яр...
# 6491296       3963  Ярославль, пос.Нагорный, Дорожная, 6а, ТРК «Яр...
# 6491297       3963  Ярославль, пос.Нагорный, Дорожная, 6а, ТРК «Яр...
# 6491298       3963  Ярославль, пос.Нагорный, Дорожная, 6а, ТРК «Яр...
#
#                          Название товара Артикул поставщика  Остаток Проба  \
# 0                   Браслет Веревка пуст  431-00-0060-30333     1.00   585
# 1                   Браслет Веревка пуст  431-00-0060-30333     1.00   585
# 2                   Браслет Веревка пуст  431-00-0060-30333     1.00   585
# 3                   Браслет Веревка пуст  431-00-0060-30333     1.00   585
# 4        Браслет Ромб двойной пуст с а/г  411-01-0035-30176     1.00   585
# ...                                  ...                ...      ...   ...
# 6491294               Подвес Крест черн.           ПК-10104     1.00   925
# 6491295               Подвес Крест черн.             ПК-064     1.00   925
# 6491296               Подвес Крест черн.             ПК-909     1.00   925
# 6491297          Серьги-пусеты с янтарем        912040357ba     1.00   585
# 6491298      Серьги-продевки с малахитом        11E280016ac     1.00   585
#
#          Чистый вес Товарное направление Товарная группа     Тип изделия 1  \
# 0              2.09                   ЦБ     ЦБ БРАСЛЕТЫ           БРАСЛЕТ
# 1              2.16                   ЦБ     ЦБ БРАСЛЕТЫ           БРАСЛЕТ
# 2              2.18                   ЦБ     ЦБ БРАСЛЕТЫ           БРАСЛЕТ
# 3              2.21                   ЦБ     ЦБ БРАСЛЕТЫ           БРАСЛЕТ
# 4              0.65                   ЦБ     ЦБ БРАСЛЕТЫ           БРАСЛЕТ
# ...             ...                  ...             ...               ...
# 6491294        4.53                   СИ    СИ ПОДВЕС БК  ПОДВЕС КУЛЬТОВЫЙ
# 6491295        3.10                   СИ    СИ ПОДВЕС БК  ПОДВЕС КУЛЬТОВЫЙ
# 6491296        4.64                   СИ    СИ ПОДВЕС БК  ПОДВЕС КУЛЬТОВЫЙ
# 6491297        1.60                  ПДК      ПДК СЕРЬГИ            СЕРЬГИ
# 6491298        2.01                  ПДК      ПДК СЕРЬГИ            СЕРЬГИ
#
#                       Тип изделия 2 Тип изделия 3  \
# 0                        БЕЗ КАМНЕЙ       КРАСНЫЙ
# 1                        БЕЗ КАМНЕЙ       КРАСНЫЙ
# 2                        БЕЗ КАМНЕЙ       КРАСНЫЙ
# 3                        БЕЗ КАМНЕЙ       КРАСНЫЙ
# 4                        БЕЗ КАМНЕЙ       КРАСНЫЙ
# ...                             ...           ...
# 6491294                  БЕЗ КАМНЕЙ        ЧЁРНЫЙ
# 6491295                  БЕЗ КАМНЕЙ        ЧЁРНЫЙ
# 6491296                  БЕЗ КАМНЕЙ        ЧЁРНЫЙ
# 6491297  С ПОЛУДРАГОЦЕННЫМИ КАМНЯМИ       КРАСНЫЙ
# 6491298  С ПОЛУДРАГОЦЕННЫМИ КАМНЯМИ       КРАСНЫЙ
#
#                             Группа цен  Скидка на изделии Запрет скидки  \
# 0        ЦБ_ЮИТ_ПУСТОТЕЛЫЕ_КОРДА <3 ГР              25.00           Нет
# 1        ЦБ_ЮИТ_ПУСТОТЕЛЫЕ_КОРДА <3 ГР              25.00           Нет
# 2        ЦБ_ЮИТ_ПУСТОТЕЛЫЕ_КОРДА <3 ГР              25.00           Нет
# 3        ЦБ_ЮИТ_ПУСТОТЕЛЫЕ_КОРДА <3 ГР              25.00           Нет
# 4            ЦБ_ПУСТОТЕЛЫЕ <=1,5 ГРАММ              30.00           Нет
# ...                                ...                ...           ...
# 6491294          СИ_ПОДВЕС_КУЛЬТ_СРЕДН              40.00           Нет
# 6491295          СИ_ПОДВЕС_КУЛЬТ_СРЕДН              40.00           Нет
# 6491296          СИ_ПОДВЕС_КУЛЬТ_СРЕДН              40.00           Нет
# 6491297                       ШОК_ЦЕНА               0.00            Да
# 6491298                       ШОК_ЦЕНА               0.00            Да
#
#                     Дизайн                  Бренд Дата закупки  \
# 0             ВЕРЕВКА ПУСТ  Значение по умолчанию   2023-02-15
# 1             ВЕРЕВКА ПУСТ  Значение по умолчанию   2023-12-07
# 2             ВЕРЕВКА ПУСТ  Значение по умолчанию   2023-12-07
# 3             ВЕРЕВКА ПУСТ  Значение по умолчанию   2023-01-26
# 4        РОМБ ДВОЙНОЙ ПУСТ              ADRIATICA   2023-04-12
# ...                    ...                    ...          ...
# 6491294           СИ КРЕСТ  Значение по умолчанию   2024-05-17
# 6491295           СИ КРЕСТ  Значение по умолчанию   2024-05-17
# 6491296           СИ КРЕСТ  Значение по умолчанию   2024-05-15
# 6491297  ДК С ОДНИМ КАМНЕМ  Значение по умолчанию   2023-06-11
# 6491298           ДК КРЕСТ  Значение по умолчанию   2023-07-08
#
#          Цена Розн., за шт Гендерный признак Ценовая корзина Товарный кластер  \
# 0                 34970.00           женские         ДЕШЕВАЯ          7645_ЦБ
# 1                 41904.00           женские         ДЕШЕВАЯ          7645_ЦБ
# 2                 42292.00           женские         ДЕШЕВАЯ          7645_ЦБ
# 3                 36593.00           женские         ДЕШЕВАЯ          7645_ЦБ
# 4                 12513.00           женские         ДЕШЕВАЯ          7730_ЦБ
# ...                    ...               ...             ...              ...
# 6491294            4148.00           унисекс         ДОРОГАЯ          6423_СИ
# 6491295            2982.00           унисекс         ДОРОГАЯ          6423_СИ
# 6491296            4815.00           унисекс         ДОРОГАЯ          6423_СИ
# 6491297            8910.00           женские         ДЕШЕВАЯ          ДК_2564
# 6491298           12795.00           женские         СРЕДНЯЯ          ДК_2565
#
#            Внутренний артикул ID Сайта  \
# 0        431-00-0060-30333_ЦБ  3778045
# 1        431-00-0060-30333_ЦБ  3778045
# 2        431-00-0060-30333_ЦБ  3778045
# 3        431-00-0060-30333_ЦБ  3778045
# 4        411-01-0035-30176_ЦБ  1674395
# ...                       ...      ...
# 6491294           ПК-10104_СИ  1892970
# 6491295             ПК-064_СИ  1672265
# 6491296             ПК-909_СИ  1838978
# 6491297       912040357ba_ПДК  1581826
# 6491298       11E280016ac_ПДК  1861739
#
#          Цена Закупки за 1 шт. (упр сс с НДС за единицу)
# 0                                                4782.59
# 1                                                7976.13
# 2                                                8042.10
# 3                                                5132.15
# 4                                                1436.74
# ...                                                  ...
# 6491294                                           883.35
# 6491295                                           604.49
# 6491296                                           904.80
# 6491297                                          4351.82
# 6491298                                          5985.29
#
# [6491299 rows x 25 columns]

# %%
center = stock[stock['Код склада'] == '3075']
center = center.groupby(by = 'Артикул поставщика', as_index=False)['Остаток'].sum()
center.columns = ['Артикул поставщика', 'Остаток на центральном складе']

# %%
kolambus = stock[stock['Код склада'] == '5442']
kolambus = kolambus.groupby(by = 'Артикул поставщика', as_index=False)['Остаток'].sum()
kolambus.columns = ['Артикул поставщика', 'Остаток на складе коламбуса']

# %%
federal = pd.read_excel(r'C:\Users\Trenkin.Sergey\Desktop\Федеральные склады 11.06.xlsx')

# %%
federal = federal['outlet_name'].tolist()

# %%
stock.columns = ['Код склада', 'name', 'Название товара',
    'Артикул поставщика', 'Остаток', 'Проба', 'Чистый вес',
    'Товарное направление', 'Товарная группа', 'Тип изделия 1',
    'Тип изделия 2', 'Тип изделия 3', 'Группа цен', 'Скидка на изделии',
    'Запрет скидки', 'Дизайн', 'Бренд', 'Дата закупки', 'Цена Розн., за шт',
    'Гендерный признак', 'Ценовая корзина', 'Товарный кластер',
    'Внутренний артикул', 'ID Сайта',
    'Цена Закупки за 1 шт. (упр сс с НДС за единицу)']

# %%
federal = stock.query('name in @federal')

# %%
federal = federal.groupby(by = 'Артикул поставщика', as_index=False)['Остаток'].sum()
federal.columns = ['Артикул поставщика', 'Остаток на федеральных складах']

# %%
federal
# Out:
#       Артикул поставщика  Остаток на федеральных складах
# 0                  К-392                            1.00
# 1                  0-017                            5.00
# 2             00-03-0858                            1.00
# 3                00008-П                            1.00
# 4                 00013Ч                            1.00
# ...                  ...                             ...
# 19609             с35-04                            6.00
# 19610            с462-20                            2.00
# 19611              с9-16                            4.00
# 19612   сCRM-026#КЕРАМИК                            1.00
# 19613              ск010                            5.00
#
# [19614 rows x 2 columns]

# %%
ids = ids.merge(federal, how='left', on='Артикул поставщика')

# %%
ids = ids.merge(kolambus, how='left', on='Артикул поставщика')

# %%
ids = ids.merge(center, how='left', on='Артикул поставщика')

# %%
ids.to_excel('предварительный.xlsx', index=False)

# %%
ids['Сумма в себестоимости на остатках'] = ids['Себестоимость'] * ids['Остаток']

# %%
zapret = pd.read_excel(r'C:\Users\Trenkin.Sergey\Desktop\запрет Артикулы к размещению.xlsx')

# %%
zapret.columns = ['ТГ', 'article', 'Описание', 'Рейтинг по размещению 30.04.2024',
    'Артикул сайта', 'Опубликован', 'Остаток на 30.04.24',
    'Себестоимость остатка на 30.04.2024',
    'Среднее количество продаж, шт/мес', 'Средняя сумма продаж, руб/мес',
    'Cредняя себестоимость, руб/мес', 'Средняя валовая прибыль,  руб/мес',
    'Средняя цена продажи, шт', 'Причина блокировки']

# %%
zapret = zapret['article'].tolist()

# %%
ids['Запрет к размещению'] = np.nan
for i in ids.index:
    if ids['Артикул поставщика'][i] in zapret:
        ids['Запрет к размещению'][i] = True
    else:
        ids['Запрет к размещению'][i] = False

# %%
ids
# Out:
#       Код склада                Название склада  \
# 0           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 1           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 2           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 3           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# 4           4616   Мытищи, Мира, 51, ТРЦ «ИЮНЬ»
# ...          ...                            ...
# 17358       3075  Центральный склад Регент Голд
# 17359       3075  Центральный склад Регент Голд
# 17360       3075  Центральный склад Регент Голд
# 17361       3075  Центральный склад Регент Голд
# 17362       3075  Центральный склад Регент Голд
#
#                                        Название товара   Артикул поставщика  \
# 0                                 Браслет Веревка пуст    431-00-0060-30333
# 1                      Браслет Ромб двойной пуст с а/г    411-01-0035-30176
# 2                                      Серьги, фианит               1241689
# 3                        серьги с бриллиантом с родир.       2436-151-00-00
# 4                                          Подвес род.            2035076/9
# ...                                                ...                  ...
# 17358           Кольцо с бриллиантами выращ., с родир.     20-12-Ф000-13341
# 17359                       Подвес икона Семистрельная     52-0Z-0000-13522
# 17360                                           Подвес  50-00-0000-13608#ER
# 17361         Подвес позолота, культивированный жемчуг               18.104
# 17362  Кольцо с бриллиантами+шайба+алм.грань, с родир.     20-33-1000-13349
#
#       Проба  Чистый вес Товарное направление  Товарная группа  \
# 0       585        2.09                   ЦБ      ЦБ БРАСЛЕТЫ
# 1       585        0.65                   ЦБ      ЦБ БРАСЛЕТЫ
# 2       585        1.98                   ИФ        ИФ СЕРЬГИ
# 3       585        3.06                   ДК        ДК СЕРЬГИ
# 4       925        0.50                   СИ     СИ ПОДВЕС БК
# ...     ...         ...                  ...              ...
# 17358   585        1.09                   ДК        ДК КОЛЬЦА
# 17359   585        1.19                   БК  БК ПОДВЕС КУЛЬТ
# 17360   585        1.09                   БК  БК ПОДВЕС ДЕКОР
# 17361   925        2.30               ВЫРИЦА   ВЫРИЦА СЕРЕБРО
# 17362   585        1.29                   ДК        ДК КОЛЬЦА
#
#              Тип изделия 1             Тип изделия 2         Тип изделия 3  \
# 0                  БРАСЛЕТ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 1                  БРАСЛЕТ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 2                   СЕРЬГИ               С ФИАНИТАМИ               КРАСНЫЙ
# 3                   СЕРЬГИ    С ДРАГОЦЕННЫМИ КАМНЯМИ               КРАСНЫЙ
# 4      ПОДВЕС ДЕКОРАТИВНЫЙ                БЕЗ КАМНЕЙ  БЕЛЫЙ С РОДИРОВАНИЕМ
# ...                    ...                       ...                   ...
# 17358               КОЛЬЦО  С ИСКУССТВЕННЫМИ КАМНЯМИ                 БЕЛЫЙ
# 17359     ПОДВЕС КУЛЬТОВЫЙ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 17360  ПОДВЕС ДЕКОРАТИВНЫЙ                БЕЗ КАМНЕЙ               КРАСНЫЙ
# 17361               ПОДВЕС                С ЖЕМЧУГОМ                ЖЕЛТЫЙ
# 17362               КОЛЬЦО    С ДРАГОЦЕННЫМИ КАМНЯМИ               КРАСНЫЙ
#
#                           Группа цен  Скидка на изделии Запрет скидки  \
# 0      ЦБ_ЮИТ_ПУСТОТЕЛЫЕ_КОРДА <3 ГР              25.00           Нет
# 1          ЦБ_ПУСТОТЕЛЫЕ <=1,5 ГРАММ              30.00           Нет
# 2                           ИФ.БК_СР              34.00           Нет
# 3                         ДК_СРЕДНЯЯ              66.00           Нет
# 4              СИ_ПОДВЕС_ДЕКОР_СРЕДН              40.00           Нет
# ...                              ...                ...           ...
# 17358                     ДК_ДОРОГАЯ               0.00           Нет
# 17359                      ИФ.БК_ДЕШ               0.00           Нет
# 17360                       ИФ.БК_СР               0.00           Нет
# 17361                  СИ_ВЫРИЦА_ДЕШ               0.00           Нет
# 17362                     ДК_СРЕДНЯЯ               0.00           Нет
#
#                   Дизайн                  Бренд  Цена Розн., за шт  \
# 0           ВЕРЕВКА ПУСТ  Значение по умолчанию           34970.00
# 1      РОМБ ДВОЙНОЙ ПУСТ              ADRIATICA           12513.00
# 2      ИФ С ОДНИМ КАМНЕМ  Значение по умолчанию           39382.00
# 3      ДК С ОДНИМ КАМНЕМ  Значение по умолчанию          163994.00
# 4              СИ ПРОЧЕЕ  Значение по умолчанию            1150.00
# ...                  ...                    ...                ...
# 17358    ДК МНОГОКАМЕНКА  Значение по умолчанию                NaN
# 17359           ИФ ИКОНА  Значение по умолчанию                NaN
# 17360          ИФ ПРОЧЕЕ  Значение по умолчанию                NaN
# 17361           В_ПРОЧЕЕ                 ВЫРИЦА                NaN
# 17362       ДК ГЕОМЕТРИЯ  Значение по умолчанию                NaN
#
#            Гендерный признак Ценовая корзина Товарный кластер  \
# 0                    женские         ДЕШЕВАЯ          7645_ЦБ
# 1                    женские         ДЕШЕВАЯ          7730_ЦБ
# 2                    женские         СРЕДНЯЯ          ИФ_1044
# 3                    женские         СРЕДНЯЯ          ДК_2090
# 4                    женские        ЛЕГКОВЕС          6400_СИ
# ...                      ...             ...              ...
# 17358                женские         ДОРОГАЯ          ДК_2027
# 17359                унисекс         ДЕШЕВАЯ          БК_1568
# 17360                Унисекс         СРЕДНЯЯ          БК_1593
# 17361  Значение по умолчанию         СРЕДНЯЯ
# 17362                женские         СРЕДНЯЯ          ДК_2020
#
#            Внутренний артикул ID Сайта  Себестоимость  Остаток  \
# 0        431-00-0060-30333_ЦБ  3778045        4782.59  3501.00
# 1        411-01-0035-30176_ЦБ  1674395        1436.74  2635.00
# 2                  1241689_ИФ  2735473        6802.13   506.00
# 3           2436-151-00-00_ДК  4058155       10755.11   334.00
# 4                2035076/9_СИ  3558970         195.00  1088.00
# ...                       ...      ...            ...      ...
# 17358    20-12-Ф000-13341 _ДК                24924.21    95.00
# 17359     52-0Z-0000-13522_БК                 4197.12    50.00
# 17360  50-00-0000-13608#ER_БК                 3980.90    55.00
# 17361           18.104_ВЫРИЦА                 1912.00   101.00
# 17362     20-33-1000-13349_ДК                 7314.37    99.00
#
#        Количество продаж за май  \
# 0                        140.00
# 1                        147.00
# 2                         25.00
# 3                          7.00
# 4                        131.00
# ...                         ...
# 17358                       NaN
# 17359                       NaN
# 17360                       NaN
# 17361                       NaN
# 17362                       NaN
#
#                                    Ссылка на изображение published  \
# 0      https://static2.585.cloud/media/products/d5758...      True
# 1      https://static2.585.cloud/media/products/6bedb...      True
# 2      https://static2.585.cloud/media/products/ff494...      True
# 3      https://static2.585.cloud/media/products/501d7...      True
# 4      https://static2.585.cloud/media/products/21c90...      True
# ...                                                  ...       ...
# 17358                                                NaN       NaN
# 17359                                                NaN       NaN
# 17360                                                NaN       NaN
# 17361                                                NaN       NaN
# 17362                                                NaN       NaN
#
#        Итоговая цена на изделии  Наценка Минимальная дата закупки  \
# 0                      12589.20     1.63               2022-08-10
# 1                       4204.37     1.93               2022-08-03
# 2                      12476.22     0.83               2022-10-10
# 3                      26763.82     1.49               2022-07-02
# 4                        331.20     0.70               2022-07-12
# ...                         ...      ...                      ...
# 17358                       NaN      NaN               2024-06-10
# 17359                       NaN      NaN               2024-06-08
# 17360                       NaN      NaN               2024-06-08
# 17361                       NaN      NaN               2024-06-11
# 17362                       NaN      NaN               2024-06-10
#
#        Количество продаж 14.03-11.06  Общая сумма продаж 14.03-11.06  \
# 0                             309.00                      4911964.79
# 1                             357.00                      1967853.00
# 2                              62.00                       791420.00
# 3                              17.00                       464700.00
# 4                             288.00                       129163.00
# ...                              ...                             ...
# 17358                            NaN                             NaN
# 17359                            NaN                             NaN
# 17360                            NaN                             NaN
# 17361                            NaN                             NaN
# 17362                            NaN                             NaN
#
#        Остаток на федеральных складах  Остаток на складе коламбуса  \
# 0                               23.00                        37.00
# 1                               14.00                        10.00
# 2                                4.00                          NaN
# 3                                3.00                         2.00
# 4                                6.00                         4.00
# ...                               ...                          ...
# 17358                             NaN                          NaN
# 17359                             NaN                          NaN
# 17360                             NaN                          NaN
# 17361                             NaN                          NaN
# 17362                             NaN                          NaN
#
#        Остаток на центральном складе  Сумма в себестоимости на остатках  \
# 0                              83.00                        16743847.59
# 1                              78.00                         3785809.90
# 2                              15.00                         3441877.78
# 3                               2.00                         3592206.74
# 4                              28.00                          212160.00
# ...                              ...                                ...
# 17358                          95.00                         2367799.95
# 17359                          50.00                          209856.00
# 17360                          55.00                          218949.50
# 17361                         101.00                          193112.00
# 17362                          99.00                          724122.63
#
#       Запрет к размещению
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 17358               False
# 17359               False
# 17360               False
# 17361               False
# 17362               False
#
# [17363 rows x 37 columns]

# %%
df['Запрет к размещению'].value_counts()
# Out:
# Запрет к размещению
# False    17311
# True        36
# Name: count, dtype: int64

# %%
ids['rank1'] = ids['Остаток на федеральных складах'].rank()
ids['rank2'] = ids['Сумма в себестоимости на остатках'].rank()
ids['rank3'] = ids['Общая сумма продаж 14.03-11.06'].rank()

# %%
ids['rank'] = (ids['rank1'] + ids['rank2'] + ids['rank3'])/3

# %%
ids = ids.sort_values(by = ['rank'], ascending=False)

# %%
ids = ids.drop(columns=['index'])

# %%
ids = ids.reset_index()
ids['Рейтинг'] = np.nan
for i in ids.index:
    ids['Рейтинг'][i] = i + 1

# %%
ids = ids.drop(columns=['rank1', 'rank2', 'rank3'])

# %%
df = df.drop(columns=['Скидка на изделии', 'level_0', 'index'])

# %%
ids.to_excel('final.xlsx', index=False)

# %%
df = pd.read_excel('final.xlsx')

# %%
ids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17363 entries, 0 to 17362
# Data columns (total 39 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Код склада                         17363 non-null  object
#  1   Название склада                    17363 non-null  object
#  2   Название товара                    17363 non-null  object
#  3   Артикул поставщика                 17363 non-null  object
#  4   Проба                              17363 non-null  object
#  5   Чистый вес                         17363 non-null  float64
#  6   Товарное направление               17363 non-null  object
#  7   Товарная группа                    17363 non-null  object
#  8   Тип изделия 1                      17363 non-null  object
#  9   Тип изделия 2                      17363 non-null  object
#  10  Тип изделия 3                      17363 non-null  object
#  11  Группа цен                         17363 non-null  object
#  12  Скидка на изделии                  17363 non-null  float64
#  13  Запрет скидки                      17363 non-null  object
#  14  Дизайн                             17363 non-null  object
#  15  Бренд                              17363 non-null  object
#  16  Цена Розн., за шт                  17251 non-null  float64
#  17  Гендерный признак                  17363 non-null  object
#  18  Ценовая корзина                    17363 non-null  object
#  19  Товарный кластер                   17363 non-null  object
#  20  Внутренний артикул                 17363 non-null  object
#  21  ID Сайта                           17363 non-null  object
#  22  Себестоимость                      17363 non-null  float64
#  23  Остаток                            17363 non-null  float64
#  24  Количество продаж за май           14595 non-null  float64
#  25  Ссылка на изображение              14688 non-null  object
#  26  published                          14688 non-null  object
#  27  Итоговая цена на изделии           17251 non-null  float64
#  28  Наценка                            17251 non-null  float64
#  29  Минимальная дата закупки           14598 non-null  datetime64[ns]
#  30  Количество продаж 14.03-11.06      16299 non-null  float64
#  31  Общая сумма продаж 14.03-11.06     16299 non-null  float64
#  32  Остаток на федеральных складах     10667 non-null  float64
#  33  Остаток на складе коламбуса        12788 non-null  float64
#  34  Остаток на центральном складе      12836 non-null  float64
#  35  Сумма в себестоимости на остатках  17363 non-null  float64
#  36  Запрет к размещению                17363 non-null  object
#  37  rank                               10229 non-null  float64
#  38  Рейтинг                            17363 non-null  float64
# dtypes: datetime64[ns](1), float64(16), object(22)
# memory usage: 5.2+ MB
